# %% [markdown]
# # Stacking [(ARIMAX + RNN) --> LR]

# %%
# 1. Import libraries
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import acf, pacf
from numpy import array
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN
from keras.layers import Dropout
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_squared_log_error
from sklearn.linear_model import LinearRegression
import keras

# %%
#2. Import dataset
data = pd.read_csv("D:\Tài liệu PTDLKD\Data_stock_VJC_VN.csv")
data
# Out:
#             time    open    high     low   close   volume
# 0     2019-03-01  117964  118955  115981  118955  1125320
# 1     2019-03-04  119451  120145  118658  119847   990660
# 2     2019-03-05  119550  119649  118459  118955  1074790
# 3     2019-03-06  118955  119946  118955  119946   939310
# 4     2019-03-07  119946  120541  119847  120343  1014890
# ...          ...     ...     ...     ...     ...      ...
# 1309  2024-05-27  108300  109400  107700  109000   638400
# 1310  2024-05-28  109900  109900  108500  109600   686800
# 1311  2024-05-29  109600  109700  107300  107900   816000
# 1312  2024-05-30  107000  108400  107000  107000   661900
# 1313  2024-05-31  107500  108800  107100  107100   719200
#
# [1314 rows x 6 columns]

# %% [markdown]
# # ARIMAX

# %%
#3. Partition the data into necessary segments
ratio = 0.8
split = int(len(data)*ratio)

x_train_a = data[:split].index
y_train_a = data[:split][['close']]
exg_train_a = data[:split][['high','low']]

x_test_a = data[split:].index
y_test_a = data[split:][['close']]
exg_test_a = data[split:][['high','low']]

# %%
#4. Function for adf testing
def adf_test(dataset):
    dftest =  adfuller (dataset, autolag='AIC') 
    print("1. ADF: ",dftest[0])
    print("2. P-Value: ", round (dftest[1],6))
    print("3. Num Of Lags: ", dftest[2])
    print("4. Critical Values :")
    for key, val in dftest [4].items():
        print("\t",key, ":", val)
    if (dftest[0] < dftest [4]["5%"] or dftest[0] < dftest[4]["1%"] or dftest[0] < dftest[4]["10%"]): 
        print ("Reject H0: Time Series is Stationary")
        return True
    else:
        print ("Failed to Reject H0: Time Series is Non-Stationary") 
        return False

# %%
#5. Check the stationarity of the data and determine d
diff_order = 0
is_stationary = False
while not is_stationary:
    if diff_order > 0:
        train_diff = pd.DataFrame(np.diff(y_train_a['close'], diff_order))
        train_diff.index = y_train_a.index[diff_order:]
        train_diff.columns = ['close']
        diff = train_diff
    else:
        diff = y_train_a

    print('-' * 50)
    print('Difference order:', diff_order) 
    if adf_test(diff['close']):
        is_stationary =  True
    else:
        diff_order += 1
print('-' * 50)
print('Choose d =', diff_order)
# Out:
# --------------------------------------------------
# Difference order: 0
# 1. ADF:  -1.9481742348714426
# 2. P-Value:  0.309749
# 3. Num Of Lags:  8
# 4. Critical Values :
# 	 1% : -3.43664125006105
# 	 5% : -2.864317735333004
# 	 10% : -2.5682489786730818
# Failed to Reject H0: Time Series is Non-Stationary
# --------------------------------------------------
# Difference order: 1
# 1. ADF:  -12.401679951518103
# 2. P-Value:  0.0
# 3. Num Of Lags:  6
# 4. Critical Values :
# 	 1% : -3.436635203238866
# 	 5% : -2.8643150683130307
# 	 10% : -2.568247558190521
# Reject H0: Time Series is Stationary
# --------------------------------------------------
# Choose d = 1

# %%
#6. From ACF and PACF, we determine the lists of p and q
acf_plot= acf(diff['close'])
pacf_plot= pacf(diff['close'])
limit_sig = (math.exp(2 * 1.96 / math.sqrt(len(diff['close']) - 3))-1) / (math.exp(2 * 1.96 / math.sqrt(len(diff['close']) - 3)) + 1)
list_q=[]
list_p=[]

# Plot ACF
plt.figure(figsize=(10, 6))
N = len(diff['close'])  
plt.plot(acf_plot, marker='o', linestyle='-') 
plt.axhline(y=0, color="gray")
plt.axhline(y=limit_sig, color='red', linestyle='--') 
plt.axhline(y=-limit_sig, color='red', linestyle='--')
plt.xticks(np.arange(0, 31, step=1))
for i, val in enumerate(acf_plot):
    if val > limit_sig:
        plt.plot(i, val, marker='o', markersize=8, color='orange', linestyle='None')
        list_q.append(i)
    if val < -limit_sig:
        plt.plot(i, val, marker='o', markersize=8, color='orange', linestyle='None')
        list_q.append(i)
plt.title('ACF')

# Plot PACF
plt.figure(figsize=(10, 6))
plt.plot(pacf_plot, marker='o', linestyle='-') 
plt.axhline(y=0, color="gray")
plt.axhline(y=limit_sig, color='red', linestyle='--') 
plt.axhline(y=-limit_sig, color='red', linestyle='--')
plt.xticks(np.arange(0, 31, step=1))
for i, val in enumerate(pacf_plot):
    if val > limit_sig:
        plt.plot(i, val, marker='o', markersize=8, color='orange', linestyle='None')
        list_p.append(i)
    if val < -limit_sig:
        plt.plot(i, val, marker='o', markersize=8, color='orange', linestyle='None')
        list_p.append(i)
plt.title('PACF')
# Out:
# Text(0.5, 1.0, 'PACF')

# %%
#7. Therefore, in addition to selecting the p and d values identified by PACF and ACF,we will also take additional p and d values from 0 to 5 and put them to the list_p and list_d
combined_p = set(list_p).union(range(0, 6))
list_p = list(combined_p)
combined_q = set(list_q).union(range(0, 6))
list_q = list(combined_q)

# %%
#8. Train the model with the new lists of p and q
signi_models = []
best_model = []
best_rmse = float('inf')

for p_value in list_p:
    for q_value in list_q:
        try:
            model_arimax = ARIMA(y_train_a, exog=exg_train_a, order=(p_value, diff_order, q_value)).fit()
            p_values = model_arimax.pvalues
            if all(p < 0.05 for p in p_values):
                signi_models.append((p_value, q_value))
            else:
                raise Exception("Model not significant")
            pred_test_a = model_arimax.predict(start=len(x_train_a), end=len(x_train_a) + len(x_test_a) - 1, exog=exg_test_a)
            rmse = np.sqrt(mean_squared_error(y_test_a, pred_test_a))
            if rmse < best_rmse:
                best_model = (p_value, q_value)
                best_rmse = rmse
        except Exception as e:
            pass
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\ProgramData\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
#9. Print the list of models that have statistical significance and the model with the lowest rmse from this list
print("List model have statistical significance:")
for model_params in signi_models:
    print("- p_value:", model_params[0], ", d_value:", diff_order, ", q_value:", model_params[1])    
print("\nBest model: p=", best_model[0], ", d=", diff_order, ", q=", best_model[1])
# Out:
# List model have statistical significance:
# - p_value: 0 , d_value: 1 , q_value: 0
# - p_value: 0 , d_value: 1 , q_value: 1
# - p_value: 0 , d_value: 1 , q_value: 3
# - p_value: 1 , d_value: 1 , q_value: 0
# - p_value: 2 , d_value: 1 , q_value: 0
# - p_value: 3 , d_value: 1 , q_value: 0
# - p_value: 4 , d_value: 1 , q_value: 0
# - p_value: 5 , d_value: 1 , q_value: 0
# - p_value: 6 , d_value: 1 , q_value: 0
# - p_value: 7 , d_value: 1 , q_value: 0
#
# Best model: p= 0 , d= 1 , q= 1

# %%
#10. Define and fit model with train data
model_arimax = ARIMA(y_train_a, exog=exg_train_a, order=(best_model[0], diff_order,best_model[1])).fit()
print(model_arimax.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  close   No. Observations:                 1051
# Model:                 ARIMA(0, 1, 1)   Log Likelihood               -8725.819
# Date:                Thu, 06 Jun 2024   AIC                          17459.638
# Time:                        01:56:22   BIC                          17479.464
# Sample:                             0   HQIC                         17467.156
#                                - 1051
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# high           0.5726      0.014     40.361      0.000       0.545       0.600
# low            0.4193      0.014     30.326      0.000       0.392       0.446
# ma.L1         -0.9775      0.013    -76.663      0.000      -1.002      -0.952
# sigma2      1.213e+06   4.76e+04     25.497      0.000    1.12e+06    1.31e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.98   Jarque-Bera (JB):               590.64
# Prob(Q):                              0.32   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.78   Skew:                            -0.81
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.29
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# # RNN

# %%
#11. Scaler data for RNN model
data_rnn=data.reset_index()['close']
scaler=MinMaxScaler(feature_range=(0,1))
data_rnn=scaler.fit_transform(np.array(data_rnn).reshape(-1,1))

# %%
#12. Split the data into train and test sets
train_size = int(ratio * len(data_rnn))
test_size = len(data_rnn) - train_size
train_rnn = data_rnn[:train_size]
test_rnn = data_rnn[train_size:]

# %%
#13. Function to create a dataset for RNN model
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return np.array(dataX), np.array(dataY)

# %%
#14. Reshape into X=t,t+1,t+2..t+99 [samples, time steps, features] and Y=t+100 [samples]
time_step = 100
x_train_rnn, y_train_rnn = create_dataset(train_rnn, time_step)
x_test_rnn, y_test_rnn = create_dataset(test_rnn, time_step)
x_train_rnn =x_train_rnn.reshape(x_train_rnn.shape[0],x_train_rnn.shape[1] , 1)
x_test_rnn = x_test_rnn.reshape(x_test_rnn.shape[0],x_test_rnn.shape[1] , 1)

# %%
#15. Proceed to define the RNN model
model_rnn = Sequential()
model_rnn.add(SimpleRNN(128, return_sequences=True, input_shape=(time_step, 1)))
model_rnn.add(Dropout(0.5))  
model_rnn.add(SimpleRNN(128))
model_rnn.add(Dropout(0.5))
model_rnn.add(Dense(1))
model_rnn.compile(loss='mean_squared_error',optimizer='adam')
# Out:
# C:\Users\THAI NGOC DUNG\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
#16. Fit model with train data
model_rnn.fit(x_train_rnn,y_train_rnn,validation_data=(x_test_rnn,y_test_rnn),epochs=50,batch_size=32,verbose=1)
# Out:
# Epoch 1/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.5657 - val_loss: 0.0167
# Epoch 2/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1554 - val_loss: 0.0072
# Epoch 3/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0854 - val_loss: 0.0048
# Epoch 4/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0669 - val_loss: 0.0036
# Epoch 5/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0504 - val_loss: 0.0022
# Epoch 6/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0400 - val_loss: 0.0018
# Epoch 7/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0328 - val_loss: 0.0016
# Epoch 8/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0259 - val_loss: 0.0015
# Epoch 9/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0217 - val_loss: 0.0014
# Epoch 10/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0214 - val_loss: 0.0014
# Epoch 11/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0207 - val_loss: 0.0013
# Epoch 12/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0179 - val_loss: 0.0014
# Epoch 13/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0166 - val_loss: 0.0016
# Epoch 14/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0165 - val_loss: 0.0013
# Epoch 15/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0161 - val_loss: 0.0013
# Epoch 16/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0127 - val_loss: 0.0012
# Epoch 17/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0130 - val_loss: 0.0012
# Epoch 18/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0126 - val_loss: 0.0019
# Epoch 19/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0128 - val_loss: 0.0011
# Epoch 20/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0129 - val_loss: 0.0012
# Epoch 21/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0108 - val_loss: 0.0013
# Epoch 22/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0089 - val_loss: 0.0011
# Epoch 23/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0097 - val_loss: 0.0013
# Epoch 24/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0096 - val_loss: 0.0012
# Epoch 25/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0097 - val_loss: 0.0012
# Epoch 26/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0091 - val_loss: 0.0011
# Epoch 27/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0083 - val_loss: 0.0010
# Epoch 28/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0082 - val_loss: 0.0010
# Epoch 29/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0076 - val_loss: 0.0013
# Epoch 30/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0074 - val_loss: 0.0010
# Epoch 31/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0075 - val_loss: 0.0011
# Epoch 32/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0082 - val_loss: 0.0010
# Epoch 33/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0071 - val_loss: 0.0012
# Epoch 34/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0058 - val_loss: 0.0012
# Epoch 35/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0065 - val_loss: 0.0011
# Epoch 36/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0072 - val_loss: 0.0013
# Epoch 37/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0059 - val_loss: 9.3411e-04
# Epoch 38/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0071 - val_loss: 9.7254e-04
# Epoch 39/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0056 - val_loss: 0.0012
# Epoch 40/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0061 - val_loss: 9.7746e-04
# Epoch 41/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0058 - val_loss: 0.0010
# Epoch 42/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0051 - val_loss: 0.0010
# Epoch 43/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0060 - val_loss: 9.6267e-04
# Epoch 44/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0055 - val_loss: 9.9868e-04
# Epoch 45/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0053 - val_loss: 9.9939e-04
# Epoch 46/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0052 - val_loss: 9.8332e-04
# Epoch 47/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0055 - val_loss: 0.0010
# Epoch 48/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0056 - val_loss: 9.3758e-04
# Epoch 49/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0045 - val_loss: 9.6929e-04
# Epoch 50/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0048 - val_loss: 9.2660e-04

# %% [markdown]
# # Linear Regression

# %%
#17. Prepare train data for LR Model using predictions on train data from ARIMAX and RNN Models
pred_train_a = model_arimax.predict(start= len(x_train_a), end=len(x_train_a) * 2 -1 , exog=exg_train_a)
pred_train_rnn=model_rnn.predict(x_train_rnn)
pred_train_rnn=scaler.inverse_transform(pred_train_rnn)
df_pred_train_a = pd.DataFrame({'arima': pred_train_a[(time_step+1):]}).reset_index().drop('index', axis=1)
df_pred_train_rnn = pd.DataFrame(pred_train_rnn, columns=['rnn'])
# Out:
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step

# %%
#18.Fit a model with inputs being the predictions of ARIMAX models, RNN model, and two features "high" and "low"
x_train_lr = pd.concat([df_pred_train_a, df_pred_train_rnn,exg_train_a[(time_step+1):].reset_index().drop(['index'], axis=1)], axis=1)
y_train_lr = y_train_a[(time_step+1):]
model_lr= LinearRegression()
model_lr.fit(x_train_lr, y_train_lr)
# Out:
# LinearRegression()

# %%
#19. Prepare test data for LR model using predictions on test data from ARIMAX and RNN models
pred_test_a = model_arimax.predict(start=len(x_train_a), end=len(x_train_a) + len(x_test_a) - 1, exog=exg_test_a)
pred_test_rnn=model_rnn.predict(x_test_rnn)
pred_test_rnn=scaler.inverse_transform(pred_test_rnn)
df_pred_test_a = pd.DataFrame({'arima': pred_test_a[(time_step+1):]}).reset_index().drop('index', axis=1)
df_pred_test_rnn = pd.DataFrame(pred_test_rnn, columns=['rnn'])
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
#20. Predict on the test data 
x_test_lr = pd.concat([df_pred_test_a, df_pred_test_rnn,exg_test_a[(time_step+1):].reset_index().drop(['index'], axis=1)], axis=1)
y_test_lr = y_test_a[(time_step+1):]
pred_test_lr = model_lr.predict(x_test_lr)

# %%
#21. Evaluate model performance using RMSE, MAPE, and MSLE
print("ARIMAX Model")
rmse = np.sqrt(mean_squared_error(pred_test_a[(time_step+1):],y_test_lr))
mape = mean_absolute_percentage_error(pred_test_a[(time_step+1):],y_test_lr) * 100
msle = mean_squared_log_error(pred_test_a[(time_step+1):],y_test_lr)
print("RMSE:", rmse)
print("MAPE:", mape ,"%")
print("MSLE:", msle)

print("\nRNN Model")
rmse = np.sqrt(mean_squared_error(pred_test_rnn,y_test_lr))
mape = mean_absolute_percentage_error(pred_test_rnn,y_test_lr) * 100
msle = mean_squared_log_error(pred_test_rnn,y_test_lr)
print("RMSE:", rmse)
print("MAPE:", mape ,"%")
print("MSLE:", msle)

print("\nStacking Model")
rmse = np.sqrt(mean_squared_error(pred_test_lr,y_test_lr))
mape = mean_absolute_percentage_error(pred_test_lr,y_test_lr) * 100
msle = mean_squared_log_error(pred_test_lr,y_test_lr)
print("RMSE:", rmse)
print("MAPE:", mape ,"%")
print("MSLE:", msle)
# Out:
# ARIMAX Model
# RMSE: 928.0006542214653
# MAPE: 0.6323947803863382 %
# MSLE: 7.548662628180806e-05
#
# RNN Model
# RMSE: 2246.6531357743966
# MAPE: 1.3499963826174217 %
# MSLE: 0.000440395642995766
#
# Stacking Model
# RMSE: 859.6830605929375
# MAPE: 0.5759748865620039 %
# MSLE: 6.481375183018241e-05

# %%
#22. Function is used to predict the high and low columns for the next 30, 60, 90 days because the ARIMAX model requires exogenous variables
def predict_by_rnn(data_rnn):
    scaler=MinMaxScaler(feature_range=(0,1))
    data_rnn=scaler.fit_transform(np.array(data_rnn).reshape(-1,1))
    
    train_size = int(ratio * len(data_rnn))
    test_size = len(data_rnn) - train_size
    train_rnn = data_rnn[:train_size]
    test_rnn = data_rnn[train_size:]
    
    time_step = 100
    x_train_rnn, y_train_rnn = create_dataset(train_rnn, time_step)
    x_test_rnn, y_test_rnn = create_dataset(test_rnn, time_step)
    x_train_rnn =x_train_rnn.reshape(x_train_rnn.shape[0],x_train_rnn.shape[1] , 1)
    x_test_rnn = x_test_rnn.reshape(x_test_rnn.shape[0],x_test_rnn.shape[1] , 1)
    
    model_rnn = Sequential()
    model_rnn.add(SimpleRNN(128, return_sequences=True, input_shape=(time_step, 1)))
    model_rnn.add(Dropout(0.5))  
    model_rnn.add(SimpleRNN(128))
    model_rnn.add(Dropout(0.5))
    model_rnn.add(Dense(1))
    model_rnn.compile(loss='mean_squared_error',optimizer='adam')
    model_rnn.fit(x_train_rnn,y_train_rnn,validation_data=(x_test_rnn,y_test_rnn),epochs=50,batch_size=32,verbose=1)
      
    x_input=test_rnn[-(time_step+1):].reshape(1,-1)
    temp_input=list(x_input)
    temp_input=temp_input[0].tolist()
    lst_output=[]
    n_steps=100
    i=0
    while(i<90):

        if(len(temp_input)>time_step):
            x_input=np.array(temp_input[1:])
            x_input=x_input.reshape(1,-1)
            x_input = x_input.reshape((1, n_steps, 1))
            yhat = model_rnn.predict(x_input, verbose=0)
            temp_input.extend(yhat[0].tolist())
            temp_input=temp_input[1:]
            lst_output.extend(yhat.tolist())
            i=i+1
        else:
            x_input = x_input.reshape((1, n_steps,1))
            yhat = model_rnn.predict(x_input, verbose=0)
            temp_input.extend(yhat[0].tolist())
            lst_output.extend(yhat.tolist())
            i=i+1
    pred_rnn=scaler.inverse_transform(lst_output)
    
    return pred_rnn

# %%
#23. Predict high and low for the next 30, 60, 90 days
high_pred_rnn = predict_by_rnn(data.reset_index()['high'])
low_pred_rnn = predict_by_rnn(data.reset_index()['low'])
# Out:
# Epoch 1/50
# C:\Users\THAI NGOC DUNG\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 0.5966 - val_loss: 0.0096
# Epoch 2/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.1739 - val_loss: 0.0086
# Epoch 3/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.1052 - val_loss: 0.0036
# Epoch 4/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0746 - val_loss: 0.0023
# Epoch 5/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0495 - val_loss: 0.0023
# Epoch 6/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0489 - val_loss: 0.0012
# Epoch 7/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0410 - val_loss: 0.0013
# Epoch 8/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0281 - val_loss: 0.0012
# Epoch 9/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0252 - val_loss: 0.0021
# Epoch 10/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0229 - val_loss: 0.0013
# Epoch 11/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0205 - val_loss: 0.0012
# Epoch 12/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0201 - val_loss: 0.0013
# Epoch 13/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0175 - val_loss: 0.0015
# Epoch 14/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0167 - val_loss: 0.0011
# Epoch 15/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0185 - val_loss: 0.0014
# Epoch 16/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0153 - val_loss: 0.0011
# Epoch 17/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0149 - val_loss: 0.0012
# Epoch 18/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0131 - val_loss: 0.0011
# Epoch 19/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0126 - val_loss: 9.8320e-04
# Epoch 20/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0115 - val_loss: 0.0013
# Epoch 21/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0115 - val_loss: 9.9417e-04
# Epoch 22/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0114 - val_loss: 0.0010
# Epoch 23/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0106 - val_loss: 9.9675e-04
# Epoch 24/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0089 - val_loss: 0.0011
# Epoch 25/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0095 - val_loss: 9.2709e-04
# Epoch 26/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0097 - val_loss: 8.8708e-04
# Epoch 27/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0094 - val_loss: 0.0010
# Epoch 28/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0080 - val_loss: 8.8690e-04
# Epoch 29/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0087 - val_loss: 0.0012
# Epoch 30/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0095 - val_loss: 9.0185e-04
# Epoch 31/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0078 - val_loss: 9.9557e-04
# Epoch 32/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0077 - val_loss: 8.4898e-04
# Epoch 33/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0076 - val_loss: 8.2084e-04
# Epoch 34/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0074 - val_loss: 8.8272e-04
# Epoch 35/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0064 - val_loss: 8.4408e-04
# Epoch 36/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0071 - val_loss: 8.9153e-04
# Epoch 37/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0057 - val_loss: 9.8323e-04
# Epoch 38/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0078 - val_loss: 7.8431e-04
# Epoch 39/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0067 - val_loss: 8.2468e-04
# Epoch 40/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0063 - val_loss: 8.6443e-04
# Epoch 41/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0056 - val_loss: 8.9033e-04
# Epoch 42/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0059 - val_loss: 7.6193e-04
# Epoch 43/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0065 - val_loss: 7.6515e-04
# Epoch 44/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0051 - val_loss: 8.4185e-04
# Epoch 45/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0061 - val_loss: 7.6179e-04
# Epoch 46/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0052 - val_loss: 8.0306e-04
# Epoch 47/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0057 - val_loss: 7.7215e-04
# Epoch 48/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0050 - val_loss: 8.1678e-04
# Epoch 49/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0050 - val_loss: 7.8485e-04
# Epoch 50/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0052 - val_loss: 8.1640e-04
# Epoch 1/50
# C:\Users\THAI NGOC DUNG\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.5536 - val_loss: 0.0106
# Epoch 2/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1269 - val_loss: 0.0054
# Epoch 3/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0792 - val_loss: 0.0025
# Epoch 4/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0668 - val_loss: 0.0017
# Epoch 5/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0431 - val_loss: 0.0018
# Epoch 6/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0357 - val_loss: 0.0020
# Epoch 7/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0252 - val_loss: 0.0017
# Epoch 8/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0267 - val_loss: 0.0014
# Epoch 9/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0239 - val_loss: 0.0012
# Epoch 10/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0213 - val_loss: 0.0015
# Epoch 11/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0199 - val_loss: 0.0012
# Epoch 12/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0148 - val_loss: 0.0014
# Epoch 13/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0157 - val_loss: 0.0013
# Epoch 14/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0163 - val_loss: 0.0011
# Epoch 15/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0138 - val_loss: 0.0011
# Epoch 16/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0121 - val_loss: 0.0010
# Epoch 17/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0129 - val_loss: 9.6130e-04
# Epoch 18/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0101 - val_loss: 9.9399e-04
# Epoch 19/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0107 - val_loss: 9.3877e-04
# Epoch 20/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0110 - val_loss: 0.0010
# Epoch 21/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0092 - val_loss: 0.0011
# Epoch 22/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0095 - val_loss: 0.0011
# Epoch 23/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0092 - val_loss: 9.5004e-04
# Epoch 24/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0075 - val_loss: 9.9059e-04
# Epoch 25/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0076 - val_loss: 9.6350e-04
# Epoch 26/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0082 - val_loss: 9.5026e-04
# Epoch 27/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0079 - val_loss: 9.3595e-04
# Epoch 28/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0075 - val_loss: 8.9945e-04
# Epoch 29/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0069 - val_loss: 0.0010
# Epoch 30/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0064 - val_loss: 8.7715e-04
# Epoch 31/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0080 - val_loss: 9.5519e-04
# Epoch 32/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0061 - val_loss: 0.0010
# Epoch 33/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0068 - val_loss: 8.4610e-04
# Epoch 34/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0068 - val_loss: 9.3784e-04
# Epoch 35/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0062 - val_loss: 9.0193e-04
# Epoch 36/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0056 - val_loss: 8.7928e-04
# Epoch 37/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0055 - val_loss: 9.2961e-04
# Epoch 38/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0060 - val_loss: 8.4186e-04
# Epoch 39/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0061 - val_loss: 9.1569e-04
# Epoch 40/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0058 - val_loss: 8.2980e-04
# Epoch 41/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0056 - val_loss: 8.6689e-04
# Epoch 42/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0052 - val_loss: 9.3286e-04
# Epoch 43/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0056 - val_loss: 8.4285e-04
# Epoch 44/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0054 - val_loss: 8.7335e-04
# Epoch 45/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0047 - val_loss: 8.0007e-04
# Epoch 46/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0055 - val_loss: 8.1886e-04
# Epoch 47/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0053 - val_loss: 8.2501e-04
# Epoch 48/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0050 - val_loss: 8.2618e-04
# Epoch 49/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0044 - val_loss: 8.3371e-04
# Epoch 50/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0044 - val_loss: 9.2215e-04

# %%
#24. Predict close for the next 30, 60, 90 days by ARIMAX model
df_high_pred_rnn = pd.DataFrame(high_pred_rnn, columns=['high'])
df_low_pred_rnn = pd.DataFrame(low_pred_rnn, columns=['low'])
exg_pred_a = pd.concat([df_high_pred_rnn, df_low_pred_rnn], axis=1)
close_pred_a = model_arimax.predict(start=len(x_train_a), end=len(x_train_a) + 89, exog=exg_pred_a)

# %%
#25. Predict close for the next 30, 60, 90 days by RNN model
x_input=test_rnn[-(time_step+1):].reshape(1,-1)
temp_input=list(x_input)
temp_input=temp_input[0].tolist()
lst_output=[]
n_steps=100
i=0
while(i<90):
    if(len(temp_input)>time_step):
        x_input=np.array(temp_input[1:])
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model_rnn.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model_rnn.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i=i+1
close_pred_rnn=scaler.inverse_transform(lst_output)

# %%
#26. Predict close for the next 30, 60, 90 days by Stacking model [(ARIMAX + RNN) --> LR]
df_close_pred_a  = pd.DataFrame({'arima': close_pred_a}).reset_index().drop('index', axis=1)
df_close_pred_rnn  = pd.DataFrame(close_pred_rnn, columns=['rnn'])
x_pred_lr = pd.concat([df_close_pred_a,df_close_pred_rnn,df_high_pred_rnn,df_low_pred_rnn], axis=1)
close_pred_stacking = model_lr.predict(x_pred_lr)

# %%
#27. Draw the plot 
plt.figure(figsize=(12, 8))

train_index = pd.RangeIndex(start=0, stop=train_size, step=1)
line1, = plt.plot(train_index, y_train_a, label="Train")

test_index = pd.RangeIndex(start=train_size, stop=train_size + test_size, step=1)
line2, = plt.plot(test_index, y_test_a, label="Test")

pred_index = pd.RangeIndex(start=train_size + 101, stop=train_size + test_size, step=1)
line3, = plt.plot(pred_index, pred_test_lr, label="Predictions")

pred90_index = pd.RangeIndex(start=len(data), stop=len(data) + 90, step=1)
line4, = plt.plot(pred90_index, close_pred_stacking, label="Next 90 days")

pred60_index = pd.RangeIndex(start=len(data), stop=len(data) + 60, step=1)
line5, = plt.plot(pred60_index, close_pred_stacking[:60], label="Next 60 days")

pred30_index = pd.RangeIndex(start=len(data), stop=len(data) + 30, step=1)
line6, = plt.plot(pred30_index, close_pred_stacking[:30], label="Next 30 days")

plt.subplots_adjust(left=0.05, right=0.95, top=0.95, bottom=0.05)
for spine in plt.gca().spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(2)

plt.legend(handles=[line1, line2, line3, line6, line5, line4])
plt.savefig("D:\Tài liệu PTDLKD\Image_Result\Stacking_VJC_82.png")
plt.show()
