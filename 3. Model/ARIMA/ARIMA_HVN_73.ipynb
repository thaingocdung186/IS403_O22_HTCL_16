# %%
# 1. Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pmdarima.arima import auto_arima
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_squared_log_error

# %%
#2. Import dataset
data = pd.read_csv("D:\Tài liệu PTDLKD\Data_stock_HVN_VN.csv")
data
# Out:
#             time   open   high    low  close   volume
# 0     2019-03-01  30274  31432  30274  31278  1231293
# 1     2019-03-04  31046  33209  31046  33131  2159830
# 2     2019-03-05  33209  36298  32668  32900  1352465
# 3     2019-03-06  32050  33054  32050  32745   815962
# 4     2019-03-07  32591  33054  32359  32436   713115
# ...          ...    ...    ...    ...    ...      ...
# 1302  2024-05-27  24200  25350  24000  25150  6719200
# 1303  2024-05-28  25300  26900  24500  26900  9317700
# 1304  2024-05-29  26900  28450  26900  28300  6449500
# 1305  2024-05-30  28300  28500  26800  27700  6116600
# 1306  2024-05-31  27700  29600  27600  27800  4053800
#
# [1307 rows x 6 columns]

# %%
#3. Partition the data into necessary segments
data_model = data[['close']]
split = int(len(data)*0.7)
train = data_model[:split]
test = data_model[split:]

# %%
#4. Using auto ARIMA to find the most suitable p, d, q and fit with model
model = auto_arima(train, trace=True, error_action='ignore', suppress_warnings=True)
model.fit(train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=13938.255, Time=0.36 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=13968.319, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=13942.337, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=13937.032, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=13968.087, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=13935.917, Time=0.11 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=13936.268, Time=0.20 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=13936.464, Time=0.33 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=13934.966, Time=0.09 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=13936.402, Time=0.11 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=13938.627, Time=0.63 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=13934.517, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=13936.432, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=13935.895, Time=0.11 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=13936.014, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=13935.303, Time=0.05 sec
#  ARIMA(1,1,3)(0,0,0)[0]             : AIC=13937.906, Time=0.33 sec
#
# Best model:  ARIMA(0,1,2)(0,0,0)[0]
# Total fit time: 2.617 seconds
# ARIMA(order=(0, 1, 2), scoring_args={}, suppress_warnings=True,
#       with_intercept=False)

# %%
#5. Check the p-value to see if it is statistically significant
print(model.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  914
# Model:               SARIMAX(0, 1, 2)   Log Likelihood               -6964.259
# Date:                Thu, 06 Jun 2024   AIC                          13934.517
# Time:                        02:37:26   BIC                          13948.967
# Sample:                             0   HQIC                         13940.033
#                                 - 914
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.1771      0.023      7.570      0.000       0.131       0.223
# ma.L2         -0.0624      0.027     -2.341      0.019      -0.115      -0.010
# sigma2      2.474e+05   8958.016     27.622      0.000     2.3e+05    2.65e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.43   Jarque-Bera (JB):                82.77
# Prob(Q):                              0.51   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.91   Skew:                             0.06
# Prob(H) (two-sided):                  0.40   Kurtosis:                         4.47
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
#6. Predict on the test data
predictions = model.predict(n_periods=len(test)+90)
predict_test = predictions[:-90]

# %%
#7. Evaluate model performance using RMSE, MAPE, and MSLE
rmse = np.sqrt(mean_squared_error(test, predict_test))
mape = mean_absolute_percentage_error(test, predict_test) * 100
msle = mean_squared_log_error(test, predict_test)
print("RMSE:", rmse)
print("MAPE:", mape ,"%")
print("MSLE:", msle)
# Out:
# RMSE: 3581.651678145861
# MAPE: 16.30426084183207 %
# MSLE: 0.06087159873137546

# %%
#8. Predict close prices for the next 30, 60, 90 days
next_30_days = predictions[-90:-60]
next_60_days = predictions[-90:-30]
next_90_days = predictions[-90:]

# %%
#9. Draw the plot
plt.figure(figsize=(12, 8))
line1, = plt.plot(train.index, train["close"], label="Train")
line2, = plt.plot(test.index, test['close'], label="Test")
line3, = plt.plot(test.index, predict_test, label="Predictions")
line4, = plt.plot(next_90_days.index, next_90_days, label="Next 90 days")
line5, = plt.plot(next_60_days.index, next_60_days, label="Next 60 days")
line6, = plt.plot(next_30_days.index, next_30_days, label="Next 30 days")
plt.subplots_adjust(left=0.05, right=0.95, top=0.95, bottom=0.05)
for spine in plt.gca().spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(2)
plt.legend(handles=[line1, line2, line3, line6, line5, line4])
plt.savefig("D:\Tài liệu PTDLKD\Image_Result\ARIMA_HVN_73.png")
plt.show()
