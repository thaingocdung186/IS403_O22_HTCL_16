# %% [markdown]
# ***
# __Tóm tắt LTSM Train (90%) và Test (10%)__
# - Dataset: Data_stock_VJC_new.csv
# ***
# __Kết quả evalutation__
# - RMSE: 2684.56
# - MAPE: 1.71757 %
# - MSLE: 0.00058
# ***

# %%
# Import necessary libraries
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import warnings
warnings.filterwarnings("ignore")
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_squared_log_error

# %%
# Import data and assign index with 'close' price
data = pd.read_csv('../Dataset/Data_stock_VJC_VN.csv')
df = data.reset_index()['close']

# %%
# Scale data
scaler = MinMaxScaler(feature_range=(0,1))
df = scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
# Split train, test and validate with ratio 9:1
split = int(len(df) * 0.9)
train_size = int(0.9 * len(df))
test_size = len(df) - train_size

train_data = df[:split]
test_data = df[split:]

# %%
# Create a function to convert an array of values into a dataset matrix
def create_sequences(dataset, time_step=1):
    dataX, dataY = [],[]
    for i in range(len(dataset)-time_step-1):
        x, y = dataset[i:(i+time_step), 0], dataset[i + time_step, 0]
        dataX.append(x)
        dataY.append(y)
    return np.array(dataX), np.array(dataY)

# %%
# Reshape
time_step = 100
X_train, y_train = create_sequences(train_data, time_step)
X_test, y_test = create_sequences(test_data, time_step)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
model = Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(X_train.shape[1],1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 18s 307ms/step - loss: 0.0931 - val_loss: 0.0121
# Epoch 2/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 208ms/step - loss: 0.0132 - val_loss: 0.0137
# Epoch 3/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 202ms/step - loss: 0.0091 - val_loss: 0.0154
# Epoch 4/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 197ms/step - loss: 0.0077 - val_loss: 0.0152
# Epoch 5/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 203ms/step - loss: 0.0070 - val_loss: 0.0147
# Epoch 6/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 213ms/step - loss: 0.0064 - val_loss: 0.0143
# Epoch 7/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 206ms/step - loss: 0.0064 - val_loss: 0.0146
# Epoch 8/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - loss: 0.0064 - val_loss: 0.0144
# Epoch 9/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - loss: 0.0055 - val_loss: 0.0141
# Epoch 10/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 216ms/step - loss: 0.0055 - val_loss: 0.0136
# Epoch 11/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step - loss: 0.0059 - val_loss: 0.0133
# Epoch 12/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - loss: 0.0051 - val_loss: 0.0130
# Epoch 13/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 206ms/step - loss: 0.0051 - val_loss: 0.0129
# Epoch 14/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - loss: 0.0043 - val_loss: 0.0124
# Epoch 15/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 163ms/step - loss: 0.0048 - val_loss: 0.0116
# Epoch 16/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 198ms/step - loss: 0.0048 - val_loss: 0.0116
# Epoch 17/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 207ms/step - loss: 0.0046 - val_loss: 0.0108
# Epoch 18/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 210ms/step - loss: 0.0037 - val_loss: 0.0107
# Epoch 19/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 203ms/step - loss: 0.0043 - val_loss: 0.0104
# Epoch 20/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 203ms/step - loss: 0.0038 - val_loss: 0.0094
# Epoch 21/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 208ms/step - loss: 0.0037 - val_loss: 0.0092
# Epoch 22/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 210ms/step - loss: 0.0038 - val_loss: 0.0087
# Epoch 23/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 219ms/step - loss: 0.0037 - val_loss: 0.0086
# Epoch 24/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 208ms/step - loss: 0.0034 - val_loss: 0.0085
# Epoch 25/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 207ms/step - loss: 0.0030 - val_loss: 0.0080
# Epoch 26/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 220ms/step - loss: 0.0031 - val_loss: 0.0077
# Epoch 27/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 216ms/step - loss: 0.0032 - val_loss: 0.0074
# Epoch 28/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 227ms/step - loss: 0.0030 - val_loss: 0.0070
# Epoch 29/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 204ms/step - loss: 0.0030 - val_loss: 0.0068
# Epoch 30/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 197ms/step - loss: 0.0027 - val_loss: 0.0065
# Epoch 31/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 218ms/step - loss: 0.0030 - val_loss: 0.0063
# Epoch 32/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 247ms/step - loss: 0.0030 - val_loss: 0.0063
# Epoch 33/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - loss: 0.0025 - val_loss: 0.0059
# Epoch 34/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 209ms/step - loss: 0.0026 - val_loss: 0.0057
# Epoch 35/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 217ms/step - loss: 0.0022 - val_loss: 0.0054
# Epoch 36/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 216ms/step - loss: 0.0026 - val_loss: 0.0050
# Epoch 37/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 220ms/step - loss: 0.0020 - val_loss: 0.0050
# Epoch 38/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 211ms/step - loss: 0.0022 - val_loss: 0.0048
# Epoch 39/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 208ms/step - loss: 0.0026 - val_loss: 0.0045
# Epoch 40/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 218ms/step - loss: 0.0021 - val_loss: 0.0045
# Epoch 41/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 222ms/step - loss: 0.0017 - val_loss: 0.0043
# Epoch 42/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - loss: 0.0021 - val_loss: 0.0041
# Epoch 43/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 205ms/step - loss: 0.0019 - val_loss: 0.0041
# Epoch 44/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 223ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 45/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 211ms/step - loss: 0.0017 - val_loss: 0.0048
# Epoch 46/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 290ms/step - loss: 0.0021 - val_loss: 0.0037
# Epoch 47/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 249ms/step - loss: 0.0015 - val_loss: 0.0037
# Epoch 48/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 298ms/step - loss: 0.0018 - val_loss: 0.0035
# Epoch 49/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 250ms/step - loss: 0.0017 - val_loss: 0.0035
# Epoch 50/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 247ms/step - loss: 0.0017 - val_loss: 0.0033
# Epoch 51/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 272ms/step - loss: 0.0014 - val_loss: 0.0034
# Epoch 52/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 263ms/step - loss: 0.0016 - val_loss: 0.0032
# Epoch 53/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 262ms/step - loss: 0.0016 - val_loss: 0.0032
# Epoch 54/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 284ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 55/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 259ms/step - loss: 0.0014 - val_loss: 0.0030
# Epoch 56/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 240ms/step - loss: 0.0014 - val_loss: 0.0031
# Epoch 57/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 6s 279ms/step - loss: 0.0014 - val_loss: 0.0029
# Epoch 58/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 238ms/step - loss: 0.0014 - val_loss: 0.0028
# Epoch 59/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 250ms/step - loss: 0.0013 - val_loss: 0.0029
# Epoch 60/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 247ms/step - loss: 0.0015 - val_loss: 0.0029
# Epoch 61/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 258ms/step - loss: 0.0014 - val_loss: 0.0036
# Epoch 62/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 254ms/step - loss: 0.0022 - val_loss: 0.0027
# Epoch 63/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 278ms/step - loss: 0.0016 - val_loss: 0.0027
# Epoch 64/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 263ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 65/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 255ms/step - loss: 0.0014 - val_loss: 0.0027
# Epoch 66/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 263ms/step - loss: 0.0013 - val_loss: 0.0029
# Epoch 67/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 238ms/step - loss: 0.0015 - val_loss: 0.0026
# Epoch 68/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 275ms/step - loss: 0.0011 - val_loss: 0.0024
# Epoch 69/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 248ms/step - loss: 0.0014 - val_loss: 0.0025
# Epoch 70/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 319ms/step - loss: 0.0013 - val_loss: 0.0031
# Epoch 71/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 242ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 72/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 270ms/step - loss: 0.0013 - val_loss: 0.0023
# Epoch 73/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 246ms/step - loss: 0.0013 - val_loss: 0.0023
# Epoch 74/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 263ms/step - loss: 0.0012 - val_loss: 0.0022
# Epoch 75/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 242ms/step - loss: 0.0012 - val_loss: 0.0024
# Epoch 76/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 256ms/step - loss: 0.0012 - val_loss: 0.0023
# Epoch 77/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 258ms/step - loss: 0.0015 - val_loss: 0.0025
# Epoch 78/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 207ms/step - loss: 0.0015 - val_loss: 0.0025
# Epoch 79/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - loss: 0.0014 - val_loss: 0.0025
# Epoch 80/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - loss: 0.0012 - val_loss: 0.0024
# Epoch 81/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 176ms/step - loss: 0.0014 - val_loss: 0.0027
# Epoch 82/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 197ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 83/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 84/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 85/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 194ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 86/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 177ms/step - loss: 0.0010 - val_loss: 0.0022
# Epoch 87/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 209ms/step - loss: 0.0011 - val_loss: 0.0024
# Epoch 88/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 228ms/step - loss: 0.0012 - val_loss: 0.0023
# Epoch 89/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 161ms/step - loss: 0.0011 - val_loss: 0.0022
# Epoch 90/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 140ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 91/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 92/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 93/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 152ms/step - loss: 0.0012 - val_loss: 0.0022
# Epoch 94/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 142ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 95/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 161ms/step - loss: 0.0011 - val_loss: 0.0023
# Epoch 96/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - loss: 0.0012 - val_loss: 0.0025
# Epoch 97/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 144ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 98/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 99/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - loss: 0.0012 - val_loss: 0.0022
# Epoch 100/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 202ms/step - loss: 0.0013 - val_loss: 0.0024

# %%
y_test_pred = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 663ms/step

# %%
y_test_pred = scaler.inverse_transform(y_test_pred)
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

# %%
# Calculate RMSE
test_rmse = np.sqrt(mean_squared_error(y_test,y_test_pred))

# Calculate MAPE
test_mape = mean_absolute_percentage_error(y_test, y_test_pred) * 100

# Calculate MLSE
test_mlse = mean_squared_log_error(y_test, y_test_pred)

print("RMSE:", test_rmse)
print("MAPE:", test_mape, "%")
print("MSLE:", test_mlse)
# Out:
# RMSE: 2684.5617165290564
# MAPE: 1.7175709917946067 %
# MSLE: 0.0005865987295271519

# %%
last_sequence = X_test[-1]
predict_90_days = []
for _ in range(90):
    input_data = last_sequence.reshape((1, time_step, 1))
    predicted_price = model.predict(input_data)[0, 0]
    last_sequence = np.roll(last_sequence, -1)
    last_sequence[-1] = predicted_price
    predict_90_days.append(predicted_price)

predict_90_days = scaler.inverse_transform(np.array(predict_90_days).reshape(-1, 1))
predict_90_days = predict_90_days.reshape(-1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 583ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step

# %%
plt.figure(figsize=(12, 8))
plt.subplots_adjust(left=0.05, right=0.95, top=0.95, bottom=0.05)
for spine in plt.gca().spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(2)
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
line1, = plt.plot(train_data_index,scaler.inverse_transform(train_data), label="Train")
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
line2, = plt.plot(test_data_index,scaler.inverse_transform(test_data), label='Test')
test_data_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
line3, = plt.plot(test_data_index,y_test_pred, label='Predictions')
predict_90_days_index = pd.RangeIndex(start=len(df)-1, stop=len(df)+89, step=1)
line4, = plt.plot(predict_90_days_index, predict_90_days[:90], label="Next 90 days")
predict_60_days_index = pd.RangeIndex(start=len(df)-1, stop=len(df)+59, step=1)
line5, = plt.plot(predict_60_days_index, predict_90_days[:60], label="Next 60 days")
predict_30_days_index = pd.RangeIndex(start=len(df)-1, stop=len(df)+29, step=1)
line6, = plt.plot(predict_30_days_index, predict_90_days[:30], label="Next 30 days")
plt.legend(handles=[line1, line2, line3, line6, line5, line4])
plt.savefig("LSTM_VJC_91.png")
plt.show()
