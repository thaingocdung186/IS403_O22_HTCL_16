# %% [markdown]
# ***
# __Tóm tắt LTSM Train (70%) và Test (30%)__
# - Dataset: Data_stock_VJC_new.csv
# ***
# __Kết quả evalutation__
# - RMSE: 1664.75
# - MAPE: 1.16307 %
# - MSLE: 0.00025
# ***

# %%
# Import necessary libraries
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import warnings
warnings.filterwarnings("ignore")
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_squared_log_error

# %%
# Import data and assign index with 'close' price
data = pd.read_csv('../Dataset/Data_stock_VJC_VN.csv')
df = data.reset_index()['close']

# %%
# Scale data
scaler = MinMaxScaler(feature_range=(0,1))
df = scaler.fit_transform(np.array(df).reshape(-1,1))

# %%
# Split train, test and validate with ratio 7:3
split = int(len(df) * 0.7)
train_size = int(0.7 * len(df))
test_size = len(df) - train_size

train_data = df[:split]
test_data = df[split:]

# %%
# Create a function to convert an array of values into a dataset matrix
def create_sequences(dataset, time_step=1):
    dataX, dataY = [],[]
    for i in range(len(dataset)-time_step-1):
        x, y = dataset[i:(i+time_step), 0], dataset[i + time_step, 0]
        dataX.append(x)
        dataY.append(y)
    return np.array(dataX), np.array(dataY)

# %%
# Reshape
time_step = 100
X_train, y_train = create_sequences(train_data, time_step)
X_test, y_test = create_sequences(test_data, time_step)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
model = Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(X_train.shape[1],1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 21s 438ms/step - loss: 0.1877 - val_loss: 0.0140
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 179ms/step - loss: 0.0215 - val_loss: 0.0300
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 338ms/step - loss: 0.0186 - val_loss: 0.0125
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 259ms/step - loss: 0.0134 - val_loss: 0.0069
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - loss: 0.0112 - val_loss: 0.0047
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 227ms/step - loss: 0.0092 - val_loss: 0.0039
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 267ms/step - loss: 0.0097 - val_loss: 0.0041
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - loss: 0.0063 - val_loss: 0.0044
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 243ms/step - loss: 0.0076 - val_loss: 0.0061
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 245ms/step - loss: 0.0073 - val_loss: 0.0047
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 178ms/step - loss: 0.0058 - val_loss: 0.0047
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 265ms/step - loss: 0.0062 - val_loss: 0.0053
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 268ms/step - loss: 0.0068 - val_loss: 0.0041
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 281ms/step - loss: 0.0066 - val_loss: 0.0047
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 249ms/step - loss: 0.0054 - val_loss: 0.0048
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 274ms/step - loss: 0.0060 - val_loss: 0.0041
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 261ms/step - loss: 0.0058 - val_loss: 0.0041
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 253ms/step - loss: 0.0053 - val_loss: 0.0044
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - loss: 0.0057 - val_loss: 0.0044
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 256ms/step - loss: 0.0045 - val_loss: 0.0041
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 275ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 292ms/step - loss: 0.0048 - val_loss: 0.0031
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 268ms/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 24/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 269ms/step - loss: 0.0050 - val_loss: 0.0033
# Epoch 25/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 262ms/step - loss: 0.0044 - val_loss: 0.0031
# Epoch 26/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 220ms/step - loss: 0.0036 - val_loss: 0.0034
# Epoch 27/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 303ms/step - loss: 0.0037 - val_loss: 0.0032
# Epoch 28/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 243ms/step - loss: 0.0039 - val_loss: 0.0036
# Epoch 29/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 218ms/step - loss: 0.0041 - val_loss: 0.0037
# Epoch 30/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 274ms/step - loss: 0.0044 - val_loss: 0.0031
# Epoch 31/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 263ms/step - loss: 0.0035 - val_loss: 0.0030
# Epoch 32/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 266ms/step - loss: 0.0032 - val_loss: 0.0027
# Epoch 33/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 319ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 34/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 309ms/step - loss: 0.0034 - val_loss: 0.0026
# Epoch 35/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 270ms/step - loss: 0.0035 - val_loss: 0.0026
# Epoch 36/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 240ms/step - loss: 0.0033 - val_loss: 0.0025
# Epoch 37/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - loss: 0.0033 - val_loss: 0.0029
# Epoch 38/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 245ms/step - loss: 0.0033 - val_loss: 0.0025
# Epoch 39/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 245ms/step - loss: 0.0031 - val_loss: 0.0024
# Epoch 40/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 275ms/step - loss: 0.0029 - val_loss: 0.0021
# Epoch 41/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - loss: 0.0035 - val_loss: 0.0023
# Epoch 42/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 211ms/step - loss: 0.0034 - val_loss: 0.0023
# Epoch 43/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - loss: 0.0033 - val_loss: 0.0025
# Epoch 44/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 45/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 244ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 46/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 250ms/step - loss: 0.0028 - val_loss: 0.0022
# Epoch 47/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 222ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 48/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 180ms/step - loss: 0.0029 - val_loss: 0.0020
# Epoch 49/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 240ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 50/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 257ms/step - loss: 0.0028 - val_loss: 0.0022
# Epoch 51/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 198ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 52/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 256ms/step - loss: 0.0032 - val_loss: 0.0021
# Epoch 53/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 251ms/step - loss: 0.0028 - val_loss: 0.0019
# Epoch 54/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 236ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 55/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 222ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 56/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 263ms/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 57/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 239ms/step - loss: 0.0024 - val_loss: 0.0016
# Epoch 58/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 233ms/step - loss: 0.0026 - val_loss: 0.0017
# Epoch 59/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 245ms/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 60/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 250ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 61/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 62/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 230ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 63/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 254ms/step - loss: 0.0023 - val_loss: 0.0018
# Epoch 64/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 261ms/step - loss: 0.0024 - val_loss: 0.0016
# Epoch 65/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 310ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 66/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 272ms/step - loss: 0.0021 - val_loss: 0.0014
# Epoch 67/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 266ms/step - loss: 0.0024 - val_loss: 0.0017
# Epoch 68/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 245ms/step - loss: 0.0020 - val_loss: 0.0017
# Epoch 69/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 274ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 70/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 253ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 71/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 227ms/step - loss: 0.0020 - val_loss: 0.0015
# Epoch 72/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 240ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 73/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 219ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 74/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 201ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 75/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 250ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 76/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - loss: 0.0020 - val_loss: 0.0014
# Epoch 77/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 256ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 78/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 298ms/step - loss: 0.0018 - val_loss: 0.0012
# Epoch 79/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 292ms/step - loss: 0.0020 - val_loss: 0.0013
# Epoch 80/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 246ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 81/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 260ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 82/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 83/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 84/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 85/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 231ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 86/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 205ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 87/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 233ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 88/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 251ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 89/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 223ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 90/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 205ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 91/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 92/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 213ms/step - loss: 0.0017 - val_loss: 0.0011
# Epoch 93/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 187ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 94/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 203ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 95/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 156ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 96/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 97/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 153ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 98/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 157ms/step - loss: 0.0016 - val_loss: 0.0010
# Epoch 99/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - loss: 0.0022 - val_loss: 0.0011
# Epoch 100/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 149ms/step - loss: 0.0016 - val_loss: 0.0011

# %%
y_test_pred = model.predict(X_test)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step

# %%
y_test_pred = scaler.inverse_transform(y_test_pred)
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

# %%
# Calculate RMSE
test_rmse = np.sqrt(mean_squared_error(y_test,y_test_pred))

# Calculate MAPE
test_mape = mean_absolute_percentage_error(y_test, y_test_pred) * 100

# Calculate MLSE
test_mlse = mean_squared_log_error(y_test, y_test_pred)

print("RMSE:", test_rmse)
print("MAPE:", test_mape, "%")
print("MSLE:", test_mlse)
# Out:
# RMSE: 1793.4182837836324
# MAPE: 1.2420923755027564 %
# MSLE: 0.0002983777358882583

# %%
last_sequence = X_test[-1]
predict_90_days = []
for _ in range(90):
    input_data = last_sequence.reshape((1, time_step, 1))
    predicted_price = model.predict(input_data)[0, 0]
    last_sequence = np.roll(last_sequence, -1)
    last_sequence[-1] = predicted_price
    predict_90_days.append(predicted_price)

predict_90_days = scaler.inverse_transform(np.array(predict_90_days).reshape(-1, 1))
predict_90_days = predict_90_days.reshape(-1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step

# %%
plt.figure(figsize=(12, 8))
plt.subplots_adjust(left=0.05, right=0.95, top=0.95, bottom=0.05)
for spine in plt.gca().spines.values():
    spine.set_edgecolor('black')
    spine.set_linewidth(2)
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
line1, = plt.plot(train_data_index,scaler.inverse_transform(train_data), label="Train")
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
line2, = plt.plot(test_data_index,scaler.inverse_transform(test_data), label='Test')
test_data_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
line3, = plt.plot(test_data_index,y_test_pred, label='Predictions')
predict_90_days_index = pd.RangeIndex(start=len(df)-1, stop=len(df)+89, step=1)
line4, = plt.plot(predict_90_days_index, predict_90_days[:90], label="Next 90 days")
predict_60_days_index = pd.RangeIndex(start=len(df)-1, stop=len(df)+59, step=1)
line5, = plt.plot(predict_60_days_index, predict_90_days[:60], label="Next 60 days")
predict_30_days_index = pd.RangeIndex(start=len(df)-1, stop=len(df)+29, step=1)
line6, = plt.plot(predict_30_days_index, predict_90_days[:30], label="Next 30 days")
plt.legend(handles=[line1, line2, line3, line6, line5, line4])
plt.savefig("LSTM_VJC_73.png")
plt.show()
